# %%
import pandas as pd
book5 = pd.read_csv('book_5(url).csv')

# %%
# 1000개의 데이터기 때문에 상위 5개 데이터 book에 저장 -> 오류 확인용
book= book5.head()

# %%
# 함수화. 반환값은 되도록 pandas 의 Series 로
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_aladin_book_details(detail_url: str) -> pd.Series:
    try:
        url = detail_url
        html = requests.get(url)
        soup = BeautifulSoup(html.text, 'html.parser')

        # Sales Point
        sp = soup.find('div', 'Ere_fs15 Ere_ht18')
        sp = sp.find('div', style='display:inline-block;')
        sales_point = sp.find('strong').text if sp else None

        # Price
        price_tag = soup.find('em', 'Ere_fs24 samnung_pink')
        price = price_tag.text if price_tag else None

        # Page Count
        page_count = None
        info_1 = soup.find('div', 'conts_info_list1')
        
        if info_1:
            for li in info_1.find_all('li'):
                if li.text.endswith('쪽'):
                    page_count = li.text[:-1]
                    break

        # Category
        category = None
        info_2 = soup.find('div', 'conts_info_list2')

        if info_2:
            category_line = info_2.find_all('li')[0]
            category_tag = category_line.find_all('a')[2] if category_line else None
            category = category_tag.text if category_tag else None

        # Review Count
        review_count = None
        review_div = soup.find('div','info_list Ere_fs15 Ere_ht18')

        if review_div:
            review_a_tags = review_div.find_all('a')
            if len(review_a_tags) > 3:
                review_count = review_a_tags[3].text.replace('리뷰(', '').replace(')', '')

        # Average Rating
        rating_tag = soup.find('a', 'Ere_sub_pink Ere_fs16 Ere_str')
        average_rating = rating_tag.text.strip() if rating_tag else None

        return pd.Series({
            "sales_point": sales_point,
            "price": price,
            "page_count": page_count,
            "category": category,
            "review_count": review_count,
            "average_rating": average_rating
        })
    
    except :
        return pd.Series({
            "sales_point": None,
            "price": None,
            "page_count": None,
            "category": None,
            "review_count": None,
            "average_rating": None
        })
    
book5[['sales_point', 'price', 'page_count', 'category', 'review_count', 'average_rating']] = book5['d_url'].apply(get_aladin_book_details)
book5
# Out:
#        no  ranking             bookname               authors  publisher  \
# 0    4001     3999        고민 싹둑 코알라 미용실          윤정 글 ;박현주 그림        김영사
# 1    4002     3999         장화 신은 개구리 보짱         최은옥 글 ;김유대 그림        김영사
# 2    4003     3999           나의 눈부신 친구     엘레나 페란테 지음 ;김지우 옮김        한길사
# 3    4004     3999    무서운 이야기 :이갑규 그림책              글·그림: 이갑규         창비
# 4    4005     3999             입이 똥꼬에게               박경효 글·그림        비룡소
# ..    ...      ...                  ...                   ...        ...
# 994  4996     4995               까만 토끼   필리파 레더스 글·그림 ;최지현 옮김    알에이치코리아
# 995  4997     4995          오싹오싹 좀비 금붕어     글: 모 오하라 ;번역: 지혜연        예림당
# 996  4998     4995               봄이 오리               지은이: 한연진  보림(보림출판사)
# 997  4999     4995         아빠, 나한테 물어봐    버나드 와버 글 ;이수지 그림·옮김        비룡소
# 998  5000     4995  살인자의 쇼핑몰 :강지영 장편소설               지은이: 강지영      자음과모음
#
#      publication_year         isbn13  addition_symbol    vol  class_no  ...  \
# 0              2023.0  9788934910992          73810.0    3.0     813.7  ...
# 1              2023.0  9788934911937          73810.0    3.0     813.7  ...
