# %% [markdown]
# # 도서데이터 추가 수집할 변수 정하기
# - 쪽수(분량)
# - (현재 문학분류 도서데이터) 문학-소분류
# - 가격
# - 응답자 반응 중 가장 많은 반응(예, 좋아해요 45%)
# - 도서별 주요 키워드 [3~5개] 문학과 관련된 키워드
# (chatbot api)
#
# - 리뷰수
# - 구매자분포
# - 평점

# %%
import pandas as pd

book = pd.read_csv('book_1.csv')
